# %%
import yt

# %%
s = yt.load('sedov_hdf5_plt_cnt_0004')
# Out:
# yt : [INFO     ] 2023-06-23 13:54:38,913 Parameters: current_time              = 8.735634525741815e-06
# yt : [INFO     ] 2023-06-23 13:54:38,916 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2023-06-23 13:54:38,918 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-06-23 13:54:38,921 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-06-23 13:54:38,924 Parameters: cosmological_simulation   = 0

# %%
field = ('flash', 'temp')
slc = yt.SlicePlot(s, 'z', field, width=(0.1, 'cm'))
slc.set_cmap(field, 'inferno')
slc.show()
# Out:
# yt : [INFO     ] 2023-06-23 13:56:32,443 xlim = 0.450000 0.550000
# yt : [INFO     ] 2023-06-23 13:56:32,446 ylim = 0.450000 0.550000
# yt : [INFO     ] 2023-06-23 13:56:32,455 xlim = 0.450000 0.550000
# yt : [INFO     ] 2023-06-23 13:56:32,458 ylim = 0.450000 0.550000
# yt : [INFO     ] 2023-06-23 13:56:32,462 Making a fixed resolution buffer of (('flash', 'temp')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
